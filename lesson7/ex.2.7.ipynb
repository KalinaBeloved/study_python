# %%
data = {
    "Date": "2024-06-22T11:30:00+03:00",
    "PreviousDate": "2024-06-21T11:30:00+03:00",
    "Timestamp": "2024-06-23T20:00:00+03:00",
    "Valute": {
        "AUD": {
            "ID": "R01010",
            "NumCode": "036",
            "CharCode": "AUD",
            "Nominal": 1,
            "Name": "Австралийский доллар",
            "Value": 58.625,
            "Previous": 56.965
        },
        "AZN": {
            "ID": "R01020A",
            "NumCode": "944",
            "CharCode": "AZN",
            "Nominal": 1,
            "Name": "Азербайджанский манат",
            "Value": 51.7409,
            "Previous": 50.2456
        },
        "GBP": {
            "ID": "R01035",
            "NumCode": "826",
            "CharCode": "GBP",
            "Nominal": 1,
            "Name": "Фунт стерлингов Соединенного королевства",
            "Value": 111.5854,
            "Previous": 108.7537
        },
        "AMD": {
            "ID": "R01060",
            "NumCode": "051",
            "CharCode": "AMD",
            "Nominal": 100,
            "Name": "Армянских драмов",
            "Value": 22.6396,
            "Previous": 22.0058
        },
        "BYN": {
            "ID": "R01090B",
            "NumCode": "933",
            "CharCode": "BYN",
            "Nominal": 1,
            "Name": "Белорусский рубль",
            "Value": 27.2683,
            "Previous": 26.8913
        },
        "BGN": {
            "ID": "R01100",
            "NumCode": "975",
            "CharCode": "BGN",
            "Nominal": 1,
            "Name": "Болгарский лев",
            "Value": 48.2065,
            "Previous": 46.9444
        },
        "BRL": {
            "ID": "R01115",
            "NumCode": "986",
            "CharCode": "BRL",
            "Nominal": 1,
            "Name": "Бразильский реал",
            "Value": 16.2134,
            "Previous": 15.6317
        },
        "HUF": {
            "ID": "R01135",
            "NumCode": "348",
            "CharCode": "HUF",
            "Nominal": 100,
            "Name": "Венгерских форинтов",
            "Value": 23.6501,
            "Previous": 23.0915
        },
        "VND": {
            "ID": "R01150",
            "NumCode": "704",
            "CharCode": "VND",
            "Nominal": 10000,
            "Name": "Вьетнамских донгов",
            "Value": 36.263,
            "Previous": 35.2165
        },
        "HKD": {
            "ID": "R01200",
            "NumCode": "344",
            "CharCode": "HKD",
            "Nominal": 1,
            "Name": "Гонконгский доллар",
            "Value": 11.2928,
            "Previous": 10.965
        },
        "GEL": {
            "ID": "R01210",
            "NumCode": "981",
            "CharCode": "GEL",
            "Nominal": 1,
            "Name": "Грузинский лари",
            "Value": 31.413,
            "Previous": 30.4291
        },
        "DKK": {
            "ID": "R01215",
            "NumCode": "208",
            "CharCode": "DKK",
            "Nominal": 1,
            "Name": "Датская крона",
            "Value": 12.6419,
            "Previous": 12.3091
        },
        "AED": {
            "ID": "R01230",
            "NumCode": "784",
            "CharCode": "AED",
            "Nominal": 1,
            "Name": "Дирхам ОАЭ",
            "Value": 23.9509,
            "Previous": 23.2587
        },
        "USD": {
            "ID": "R01235",
            "NumCode": "840",
            "CharCode": "USD",
            "Nominal": 1,
            "Name": "Доллар США",
            "Value": 87.9595,
            "Previous": 85.4176
        },
        "EUR": {
            "ID": "R01239",
            "NumCode": "978",
            "CharCode": "EUR",
            "Nominal": 1,
            "Name": "Евро",
            "Value": 94.2606,
            "Previous": 91.4543
        },
        "EGP": {
            "ID": "R01240",
            "NumCode": "818",
            "CharCode": "EGP",
            "Nominal": 10,
            "Name": "Египетских фунтов",
            "Value": 18.4366,
            "Previous": 17.9038
        },
        "INR": {
            "ID": "R01270",
            "NumCode": "356",
            "CharCode": "INR",
            "Nominal": 10,
            "Name": "Индийских рупий",
            "Value": 10.5232,
            "Previous": 10.2264
        },
        "IDR": {
            "ID": "R01280",
            "NumCode": "360",
            "CharCode": "IDR",
            "Nominal": 10000,
            "Name": "Индонезийских рупий",
            "Value": 53.5685,
            "Previous": 52.1857
        },
        "KZT": {
            "ID": "R01335",
            "NumCode": "398",
            "CharCode": "KZT",
            "Nominal": 100,
            "Name": "Казахстанских тенге",
            "Value": 19.1383,
            "Previous": 18.5791
        },
        "CAD": {
            "ID": "R01350",
            "NumCode": "124",
            "CharCode": "CAD",
            "Nominal": 1,
            "Name": "Канадский доллар",
            "Value": 64.2134,
            "Previous": 62.3077
        },
        "QAR": {
            "ID": "R01355",
            "NumCode": "634",
            "CharCode": "QAR",
            "Nominal": 1,
            "Name": "Катарский риал",
            "Value": 24.1647,
            "Previous": 23.4664
        },
        "KGS": {
            "ID": "R01370",
            "NumCode": "417",
            "CharCode": "KGS",
            "Nominal": 10,
            "Name": "Киргизских сомов",
            "Value": 10.1384,
            "Previous": 98.2976
        },
        "CNY": {
            "ID": "R01375",
            "NumCode": "156",
            "CharCode": "CNY",
            "Nominal": 1,
            "Name": "Китайский юань",
            "Value": 12.0455,
            "Previous": 11.5185
        },
        "MDL": {
            "ID": "R01500",
            "NumCode": "498",
            "CharCode": "MDL",
            "Nominal": 10,
            "Name": "Молдавских леев",
            "Value": 49.2285,
            "Previous": 47.7882
        },
        "NZD": {
            "ID": "R01530",
            "NumCode": "554",
            "CharCode": "NZD",
            "Nominal": 1,
            "Name": "Новозеландский доллар",
            "Value": 53.8576,
            "Previous": 52.408
        },
        "NOK": {
            "ID": "R01535",
            "NumCode": "578",
            "CharCode": "NOK",
            "Nominal": 10,
            "Name": "Норвежских крон",
            "Value": 83.4998,
            "Previous": 80.8664
        },
        "PLN": {
            "ID": "R01565",
            "NumCode": "985",
            "CharCode": "PLN",
            "Nominal": 1,
            "Name": "Польский злотый",
            "Value": 21.7039,
            "Previous": 21.1718
        },
        "RON": {
            "ID": "R01585F",
            "NumCode": "946",
            "CharCode": "RON",
            "Nominal": 1,
            "Name": "Румынский лей",
            "Value": 18.9018,
            "Previous": 18.4078
        },
        "SGD": {
            "ID": "R01625",
            "NumCode": "702",
            "CharCode": "SGD",
            "Nominal": 1,
            "Name": "Сингапурский доллар",
            "Value": 64.9867,
            "Previous": 63.2208
        },
        "TJS": {
            "ID": "R01670",
            "NumCode": "972",
            "CharCode": "TJS",
            "Nominal": 10,
            "Name": "Таджикских сомони",
            "Value": 82.6858,
            "Previous": 80.1832
        },
        "THB": {
            "ID": "R01675",
            "NumCode": "764",
            "CharCode": "THB",
            "Nominal": 10,
            "Name": "Таиландских батов",
            "Value": 23.9626,
            "Previous": 23.2682
        },
        "TRY": {
            "ID": "R01700J",
            "NumCode": "949",
            "CharCode": "TRY",
            "Nominal": 10,
            "Name": "Турецких лир",
            "Value": 26.9811,
            "Previous": 26.2927
        },
        "TMT": {
            "ID": "R01710A",
            "NumCode": "934",
            "CharCode": "TMT",
            "Nominal": 1,
            "Name": "Новый туркменский манат",
            "Value": 25.1313,
            "Previous": 24.405
        },
        "UZS": {
            "ID": "R01717",
            "NumCode": "860",
            "CharCode": "UZS",
            "Nominal": 10000,
            "Name": "Узбекских сумов",
            "Value": 69.5893,
            "Previous": 67.5563
        },
        "UAH": {
            "ID": "R01720",
            "NumCode": "980",
            "CharCode": "UAH",
            "Nominal": 10,
            "Name": "Украинских гривен",
            "Value": 21.7085,
            "Previous": 21.0709
        },
        "CZK": {
            "ID": "R01760",
            "NumCode": "203",
            "CharCode": "CZK",
            "Nominal": 10,
            "Name": "Чешских крон",
            "Value": 37.6845,
            "Previous": 36.7799
        },
        "SEK": {
            "ID": "R01770",
            "NumCode": "752",
            "CharCode": "SEK",
            "Nominal": 10,
            "Name": "Шведских крон",
            "Value": 84.197,
            "Previous": 81.8757
        },
        "CHF": {
            "ID": "R01775",
            "NumCode": "756",
            "CharCode": "CHF",
            "Nominal": 1,
            "Name": "Швейцарский франк",
            "Value": 98.6093,
            "Previous": 96.018
        },
        "RSD": {
            "ID": "R01805F",
            "NumCode": "941",
            "CharCode": "RSD",
            "Nominal": 100,
            "Name": "Сербских динаров",
            "Value": 80.5573,
            "Previous": 78.402
        },
        "ZAR": {
            "ID": "R01810",
            "NumCode": "710",
            "CharCode": "ZAR",
            "Nominal": 10,
            "Name": "Южноафриканских рэндов",
            "Value": 48.9823,
            "Previous": 47.1905
        },
        "KRW": {
            "ID": "R01815",
            "NumCode": "410",
            "CharCode": "KRW",
            "Nominal": 1000,
            "Name": "Вон Республики Корея",
            "Value": 63.3577,
            "Previous": 61.6867
        },
        "JPY": {
            "ID": "R01820",
            "NumCode": "392",
            "CharCode": "JPY",
            "Nominal": 100,
            "Name": "Японских иен",
            "Value": 55.3204,
            "Previous": 54.0515
        }
    }
}

class Rate:
    def __init__(self, diff = False):
        self.diff = diff
    
    def eur(self):
        if self.diff:
            return data["Valute"]['EUR']['Value'] - data["Valute"]['EUR']['Previous']
        else:
            return data["Valute"]['EUR']['Value'] 

    def usd(self):
        if self.diff:
            return data["Valute"]['USD']['Value'] - data["Valute"]['USD']['Previous']
        else:
            return data["Valute"]['USD']['Value']
        
result = Rate(diff = True)
print(result.eur(), result.usd())
# Out:
# 2.806299999999993 2.5419000000000125

# %% [markdown]
# Задание 2
# Добавьте в класс Rate параметр diff (со значениями True или False), который в случае значения True в методах eur и usd будет возвращать не курс валюты, а изменение по сравнению в прошлым значением. Считайте, self.diff будет принимать значение True только при возврате значения курса. При отображении всей информации о валюте он не используется.
